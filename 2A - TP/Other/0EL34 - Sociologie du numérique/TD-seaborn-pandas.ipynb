# %% [markdown]
# ## TD : Manipulation des bibliothèques Seaborn et Pandas

# %%
# Pandas : librairie des datascientists sous Python
import pandas as pd
# Seaborn : librairie sympathique pour la data visualization 
import seaborn as sb
#Son extension seaborn objets (elle nous servira pour les stripplots)
import seaborn.objects as so
# Matplotlib.pyplot, des fonctions et objets de matplotlib qui ne sont pas dans pandas
import matplotlib.pyplot as plt

# %% [markdown]
# PARTIE I : Manipulation des bases de données
#
# Supposons qu'avant d'importer ma base de données je veuille plus d'informations sur la fonction que je vais utiliser. J'utilise donc la fonction help qui est une fonction de base de python qui me donne la documentation d'une fonction. J'y trouve les arguments à y insérer et les décrit.

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# read_csv(filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]', *, sep: 'str | None | lib.NoDefault' = <no_default>, delimiter: 'str | None | lib.NoDefault' = None, header: "int | Sequence[int] | None | Literal['infer']" = 'infer', names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>, index_col: 'IndexLabel | Literal[False] | None' = None, usecols: 'UsecolsArgType' = None, dtype: 'DtypeArg | None' = None, engine: 'CSVEngine | None' = None, converters: 'Mapping[Hashable, Callable] | None' = None, true_values: 'list | None' = None, false_values: 'list | None' = None, skipinitialspace: 'bool' = False, skiprows: 'list[int] | int | Callable[[Hashable], bool] | None' = None, skipfooter: 'int' = 0, nrows: 'int | None' = None, na_values: 'Hashable | Iterable[Hashable] | Mapping[Hashable, Iterable[Hashable]] | None' = None, keep_default_na: 'bool' = True, na_filter: 'bool' = True, verbose: 'bool | lib.NoDefault' = <no_default>, skip_blank_lines: 'bool' = True, parse_dates: 'bool | Sequence[Hashable] | None' = None, infer_datetime_format: 'bool | lib.NoDefault' = <no_default>, keep_date_col: 'bool | lib.NoDefault' = <no_default>, date_parser: 'Callable | lib.NoDefault' = <no_default>, date_format: 'str | dict[Hashable, str] | None' = None, dayfirst: 'bool' = False, cache_dates: 'bool' = True, iterator: 'bool' = False, chunksize: 'int | None' = None, compression: 'CompressionOptions' = 'infer', thousands: 'str | None' = None, decimal: 'str' = '.', lineterminator: 'str | None' = None, quotechar: 'str' = '"', quoting: 'int' = 0, doublequote: 'bool' = True, escapechar: 'str | None' = None, comment: 'str | None' = None, encoding: 'str | None' = None, encoding_errors: 'str | None' = 'strict', dialect: 'str | csv.Dialect | None' = None, on_bad_lines: 'str' = 'error', delim_whitespace: 'bool | lib.NoDefault' = <no_default>, low_memory: 'bool' = True, memory_map: 'bool' = False, float_precision: "Literal['high', 'legacy'] | None" = None, storage_options: 'StorageOptions | None' = None, dtype_backend: 'DtypeBackend | lib.NoDefault' = <no_default>) -> 'DataFrame | TextFileReader'
#     Read a comma-separated values (csv) file into DataFrame.
#
#     Also supports optionally iterating or breaking of the file
#     into chunks.
#
#     Additional help can be found in the online docs for
#     `IO Tools <https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html>`_.
#
#     Parameters
#     ----------
#     filepath_or_buffer : str, path object or file-like object
#         Any valid string path is acceptable. The string could be a URL. Valid
#         URL schemes include http, ftp, s3, gs, and file. For file URLs, a host is
#         expected. A local file could be: file://localhost/path/to/table.csv.
#
#         If you want to pass in a path object, pandas accepts any ``os.PathLike``.
#
#         By file-like object, we refer to objects with a ``read()`` method, such as
#         a file handle (e.g. via builtin ``open`` function) or ``StringIO``.
#     sep : str, default ','
#         Character or regex pattern to treat as the delimiter. If ``sep=None``, the
#         C engine cannot automatically detect
#         the separator, but the Python parsing engine can, meaning the latter will
#         be used and automatically detect the separator from only the first valid
#         row of the file by Python's builtin sniffer tool, ``csv.Sniffer``.
#         In addition, separators longer than 1 character and different from
#         ``'\s+'`` will be interpreted as regular expressions and will also force
#         the use of the Python parsing engine. Note that regex delimiters are prone
#         to ignoring quoted data. Regex example: ``'\r\t'``.
#     delimiter : str, optional
#         Alias for ``sep``.
#     header : int, Sequence of int, 'infer' or None, default 'infer'
#         Row number(s) containing column labels and marking the start of the
#         data (zero-indexed). Default behavior is to infer the column names: if no ``names``
#         are passed the behavior is identical to ``header=0`` and column
#         names are inferred from the first line of the file, if column
#         names are passed explicitly to ``names`` then the behavior is identical to
#         ``header=None``. Explicitly pass ``header=0`` to be able to
#         replace existing names. The header can be a list of integers that
#         specify row locations for a :class:`~pandas.MultiIndex` on the columns
#         e.g. ``[0, 1, 3]``. Intervening rows that are not specified will be
#         skipped (e.g. 2 in this example is skipped). Note that this
#         parameter ignores commented lines and empty lines if
#         ``skip_blank_lines=True``, so ``header=0`` denotes the first line of
#         data rather than the first line of the file.
#     names : Sequence of Hashable, optional
#         Sequence of column labels to apply. If the file contains a header row,
#         then you should explicitly pass ``header=0`` to override the column names.
#         Duplicates in this list are not allowed.
#     index_col : Hashable, Sequence of Hashable or False, optional
#       Column(s) to use as row label(s), denoted either by column labels or column
#       indices.  If a sequence of labels or indices is given, :class:`~pandas.MultiIndex`
#       will be formed for the row labels.
#
#       Note: ``index_col=False`` can be used to force pandas to *not* use the first
#       column as the index, e.g., when you have a malformed file with delimiters at
#       the end of each line.
#     usecols : Sequence of Hashable or Callable, optional
#         Subset of columns to select, denoted either by column labels or column indices.
#         If list-like, all elements must either
#         be positional (i.e. integer indices into the document columns) or strings
#         that correspond to column names provided either by the user in ``names`` or
#         inferred from the document header row(s). If ``names`` are given, the document
#         header row(s) are not taken into account. For example, a valid list-like
#         ``usecols`` parameter would be ``[0, 1, 2]`` or ``['foo', 'bar', 'baz']``.
#         Element order is ignored, so ``usecols=[0, 1]`` is the same as ``[1, 0]``.
#         To instantiate a :class:`~pandas.DataFrame` from ``data`` with element order
#         preserved use ``pd.read_csv(data, usecols=['foo', 'bar'])[['foo', 'bar']]``
#         for columns in ``['foo', 'bar']`` order or
#         ``pd.read_csv(data, usecols=['foo', 'bar'])[['bar', 'foo']]``
#         for ``['bar', 'foo']`` order.
#
#         If callable, the callable function will be evaluated against the column
#         names, returning names where the callable function evaluates to ``True``. An
#         example of a valid callable argument would be ``lambda x: x.upper() in
#         ['AAA', 'BBB', 'DDD']``. Using this parameter results in much faster
#         parsing time and lower memory usage.
#     dtype : dtype or dict of {Hashable : dtype}, optional
#         Data type(s) to apply to either the whole dataset or individual columns.
#         E.g., ``{'a': np.float64, 'b': np.int32, 'c': 'Int64'}``
#         Use ``str`` or ``object`` together with suitable ``na_values`` settings
#         to preserve and not interpret ``dtype``.
#         If ``converters`` are specified, they will be applied INSTEAD
#         of ``dtype`` conversion.
#
#         .. versionadded:: 1.5.0
#
#             Support for ``defaultdict`` was added. Specify a ``defaultdict`` as input where
#             the default determines the ``dtype`` of the columns which are not explicitly
#             listed.
#     engine : {'c', 'python', 'pyarrow'}, optional
#         Parser engine to use. The C and pyarrow engines are faster, while the python engine
#         is currently more feature-complete. Multithreading is currently only supported by
#         the pyarrow engine.
#
#         .. versionadded:: 1.4.0
#
#             The 'pyarrow' engine was added as an *experimental* engine, and some features
#             are unsupported, or may not work correctly, with this engine.
#     converters : dict of {Hashable : Callable}, optional
#         Functions for converting values in specified columns. Keys can either
#         be column labels or column indices.
#     true_values : list, optional
#         Values to consider as ``True`` in addition to case-insensitive variants of 'True'.
#     false_values : list, optional
#         Values to consider as ``False`` in addition to case-insensitive variants of 'False'.
#     skipinitialspace : bool, default False
#         Skip spaces after delimiter.
#     skiprows : int, list of int or Callable, optional
#         Line numbers to skip (0-indexed) or number of lines to skip (``int``)
#         at the start of the file.
#
#         If callable, the callable function will be evaluated against the row
#         indices, returning ``True`` if the row should be skipped and ``False`` otherwise.
#         An example of a valid callable argument would be ``lambda x: x in [0, 2]``.
#     skipfooter : int, default 0
#         Number of lines at bottom of file to skip (Unsupported with ``engine='c'``).
#     nrows : int, optional
#         Number of rows of file to read. Useful for reading pieces of large files.
#     na_values : Hashable, Iterable of Hashable or dict of {Hashable : Iterable}, optional
#         Additional strings to recognize as ``NA``/``NaN``. If ``dict`` passed, specific
#         per-column ``NA`` values.  By default the following values are interpreted as
#         ``NaN``: " ", "#N/A", "#N/A N/A", "#NA", "-1.#IND", "-1.#QNAN", "-NaN", "-nan",
#         "1.#IND", "1.#QNAN", "<NA>", "N/A", "NA", "NULL", "NaN", "None",
#         "n/a", "nan", "null ".
#
#     keep_default_na : bool, default True
#         Whether or not to include the default ``NaN`` values when parsing the data.
#         Depending on whether ``na_values`` is passed in, the behavior is as follows:
#
#         * If ``keep_default_na`` is ``True``, and ``na_values`` are specified, ``na_values``
#           is appended to the default ``NaN`` values used for parsing.
#         * If ``keep_default_na`` is ``True``, and ``na_values`` are not specified, only
#           the default ``NaN`` values are used for parsing.
#         * If ``keep_default_na`` is ``False``, and ``na_values`` are specified, only
#           the ``NaN`` values specified ``na_values`` are used for parsing.
#         * If ``keep_default_na`` is ``False``, and ``na_values`` are not specified, no
#           strings will be parsed as ``NaN``.
#
#         Note that if ``na_filter`` is passed in as ``False``, the ``keep_default_na`` and
#         ``na_values`` parameters will be ignored.
#     na_filter : bool, default True
#         Detect missing value markers (empty strings and the value of ``na_values``). In
#         data without any ``NA`` values, passing ``na_filter=False`` can improve the
#         performance of reading a large file.
#     verbose : bool, default False
#         Indicate number of ``NA`` values placed in non-numeric columns.
#
#         .. deprecated:: 2.2.0
#     skip_blank_lines : bool, default True
#         If ``True``, skip over blank lines rather than interpreting as ``NaN`` values.
#     parse_dates : bool, list of Hashable, list of lists or dict of {Hashable : list}, default False
#         The behavior is as follows:
#
#         * ``bool``. If ``True`` -> try parsing the index. Note: Automatically set to
#           ``True`` if ``date_format`` or ``date_parser`` arguments have been passed.
#         * ``list`` of ``int`` or names. e.g. If ``[1, 2, 3]`` -> try parsing columns 1, 2, 3
#           each as a separate date column.
#         * ``list`` of ``list``. e.g.  If ``[[1, 3]]`` -> combine columns 1 and 3 and parse
#           as a single date column. Values are joined with a space before parsing.
#         * ``dict``, e.g. ``{'foo' : [1, 3]}`` -> parse columns 1, 3 as date and call
#           result 'foo'. Values are joined with a space before parsing.
#
#         If a column or index cannot be represented as an array of ``datetime``,
#         say because of an unparsable value or a mixture of timezones, the column
#         or index will be returned unaltered as an ``object`` data type. For
#         non-standard ``datetime`` parsing, use :func:`~pandas.to_datetime` after
#         :func:`~pandas.read_csv`.
#
#         Note: A fast-path exists for iso8601-formatted dates.
#     infer_datetime_format : bool, default False
#         If ``True`` and ``parse_dates`` is enabled, pandas will attempt to infer the
#         format of the ``datetime`` strings in the columns, and if it can be inferred,
#         switch to a faster method of parsing them. In some cases this can increase
#         the parsing speed by 5-10x.
#
#         .. deprecated:: 2.0.0
#             A strict version of this argument is now the default, passing it has no effect.
#
#     keep_date_col : bool, default False
#         If ``True`` and ``parse_dates`` specifies combining multiple columns then
#         keep the original columns.
#     date_parser : Callable, optional
#         Function to use for converting a sequence of string columns to an array of
#         ``datetime`` instances. The default uses ``dateutil.parser.parser`` to do the
#         conversion. pandas will try to call ``date_parser`` in three different ways,
#         advancing to the next if an exception occurs: 1) Pass one or more arrays
#         (as defined by ``parse_dates``) as arguments; 2) concatenate (row-wise) the
#         string values from the columns defined by ``parse_dates`` into a single array
#         and pass that; and 3) call ``date_parser`` once for each row using one or
#         more strings (corresponding to the columns defined by ``parse_dates``) as
#         arguments.
#
#         .. deprecated:: 2.0.0
#            Use ``date_format`` instead, or read in as ``object`` and then apply
#            :func:`~pandas.to_datetime` as-needed.
#     date_format : str or dict of column -> format, optional
#         Format to use for parsing dates when used in conjunction with ``parse_dates``.
#         The strftime to parse time, e.g. :const:`"%d/%m/%Y"`. See
#         `strftime documentation
#         <https://docs.python.org/3/library/datetime.html
#         #strftime-and-strptime-behavior>`_ for more information on choices, though
#         note that :const:`"%f"` will parse all the way up to nanoseconds.
#         You can also pass:
#
#         - "ISO8601", to parse any `ISO8601 <https://en.wikipedia.org/wiki/ISO_8601>`_
#             time string (not necessarily in exactly the same format);
#         - "mixed", to infer the format for each element individually. This is risky,
#             and you should probably use it along with `dayfirst`.
#
#         .. versionadded:: 2.0.0
#     dayfirst : bool, default False
#         DD/MM format dates, international and European format.
#     cache_dates : bool, default True
#         If ``True``, use a cache of unique, converted dates to apply the ``datetime``
#         conversion. May produce significant speed-up when parsing duplicate
#         date strings, especially ones with timezone offsets.
#
#     iterator : bool, default False
#         Return ``TextFileReader`` object for iteration or getting chunks with
#         ``get_chunk()``.
#     chunksize : int, optional
#         Number of lines to read from the file per chunk. Passing a value will cause the
#         function to return a ``TextFileReader`` object for iteration.
#         See the `IO Tools docs
#         <https://pandas.pydata.org/pandas-docs/stable/io.html#io-chunking>`_
#         for more information on ``iterator`` and ``chunksize``.
#
#     compression : str or dict, default 'infer'
#         For on-the-fly decompression of on-disk data. If 'infer' and 'filepath_or_buffer' is
#         path-like, then detect compression from the following extensions: '.gz',
#         '.bz2', '.zip', '.xz', '.zst', '.tar', '.tar.gz', '.tar.xz' or '.tar.bz2'
#         (otherwise no compression).
#         If using 'zip' or 'tar', the ZIP file must contain only one data file to be read in.
#         Set to ``None`` for no decompression.
#         Can also be a dict with key ``'method'`` set
#         to one of {``'zip'``, ``'gzip'``, ``'bz2'``, ``'zstd'``, ``'xz'``, ``'tar'``} and
#         other key-value pairs are forwarded to
#         ``zipfile.ZipFile``, ``gzip.GzipFile``,
#         ``bz2.BZ2File``, ``zstandard.ZstdDecompressor``, ``lzma.LZMAFile`` or
#         ``tarfile.TarFile``, respectively.
#         As an example, the following could be passed for Zstandard decompression using a
#         custom compression dictionary:
#         ``compression={'method': 'zstd', 'dict_data': my_compression_dict}``.
#
#         .. versionadded:: 1.5.0
#             Added support for `.tar` files.
#
#         .. versionchanged:: 1.4.0 Zstandard support.
#
#     thousands : str (length 1), optional
#         Character acting as the thousands separator in numerical values.
#     decimal : str (length 1), default '.'
#         Character to recognize as decimal point (e.g., use ',' for European data).
#     lineterminator : str (length 1), optional
#         Character used to denote a line break. Only valid with C parser.
#     quotechar : str (length 1), optional
#         Character used to denote the start and end of a quoted item. Quoted
#         items can include the ``delimiter`` and it will be ignored.
#     quoting : {0 or csv.QUOTE_MINIMAL, 1 or csv.QUOTE_ALL, 2 or csv.QUOTE_NONNUMERIC, 3 or csv.QUOTE_NONE}, default csv.QUOTE_MINIMAL
#         Control field quoting behavior per ``csv.QUOTE_*`` constants. Default is
#         ``csv.QUOTE_MINIMAL`` (i.e., 0) which implies that only fields containing special
#         characters are quoted (e.g., characters defined in ``quotechar``, ``delimiter``,
#         or ``lineterminator``.
#     doublequote : bool, default True
#        When ``quotechar`` is specified and ``quoting`` is not ``QUOTE_NONE``, indicate
#        whether or not to interpret two consecutive ``quotechar`` elements INSIDE a
#        field as a single ``quotechar`` element.
#     escapechar : str (length 1), optional
#         Character used to escape other characters.
#     comment : str (length 1), optional
#         Character indicating that the remainder of line should not be parsed.
#         If found at the beginning
#         of a line, the line will be ignored altogether. This parameter must be a
#         single character. Like empty lines (as long as ``skip_blank_lines=True``),
#         fully commented lines are ignored by the parameter ``header`` but not by
#         ``skiprows``. For example, if ``comment='#'``, parsing
#         ``#empty\na,b,c\n1,2,3`` with ``header=0`` will result in ``'a,b,c'`` being
#         treated as the header.
#     encoding : str, optional, default 'utf-8'
#         Encoding to use for UTF when reading/writing (ex. ``'utf-8'``). `List of Python
#         standard encodings
#         <https://docs.python.org/3/library/codecs.html#standard-encodings>`_ .
#
#     encoding_errors : str, optional, default 'strict'
#         How encoding errors are treated. `List of possible values
#         <https://docs.python.org/3/library/codecs.html#error-handlers>`_ .
#
#         .. versionadded:: 1.3.0
#
#     dialect : str or csv.Dialect, optional
#         If provided, this parameter will override values (default or not) for the
#         following parameters: ``delimiter``, ``doublequote``, ``escapechar``,
#         ``skipinitialspace``, ``quotechar``, and ``quoting``. If it is necessary to
#         override values, a ``ParserWarning`` will be issued. See ``csv.Dialect``
#         documentation for more details.
#     on_bad_lines : {'error', 'warn', 'skip'} or Callable, default 'error'
#         Specifies what to do upon encountering a bad line (a line with too many fields).
#         Allowed values are :
#
#         - ``'error'``, raise an Exception when a bad line is encountered.
#         - ``'warn'``, raise a warning when a bad line is encountered and skip that line.
#         - ``'skip'``, skip bad lines without raising or warning when they are encountered.
#
#         .. versionadded:: 1.3.0
#
#         .. versionadded:: 1.4.0
#
#             - Callable, function with signature
#               ``(bad_line: list[str]) -> list[str] | None`` that will process a single
#               bad line. ``bad_line`` is a list of strings split by the ``sep``.
#               If the function returns ``None``, the bad line will be ignored.
#               If the function returns a new ``list`` of strings with more elements than
#               expected, a ``ParserWarning`` will be emitted while dropping extra elements.
#               Only supported when ``engine='python'``
#
#         .. versionchanged:: 2.2.0
#
#             - Callable, function with signature
#               as described in `pyarrow documentation
#               <https://arrow.apache.org/docs/python/generated/pyarrow.csv.ParseOptions.html
#               #pyarrow.csv.ParseOptions.invalid_row_handler>`_ when ``engine='pyarrow'``
#
#     delim_whitespace : bool, default False
#         Specifies whether or not whitespace (e.g. ``' '`` or ``'\t'``) will be
#         used as the ``sep`` delimiter. Equivalent to setting ``sep='\s+'``. If this option
#         is set to ``True``, nothing should be passed in for the ``delimiter``
#         parameter.
#
#         .. deprecated:: 2.2.0
#             Use ``sep="\s+"`` instead.
#     low_memory : bool, default True
#         Internally process the file in chunks, resulting in lower memory use
#         while parsing, but possibly mixed type inference.  To ensure no mixed
#         types either set ``False``, or specify the type with the ``dtype`` parameter.
#         Note that the entire file is read into a single :class:`~pandas.DataFrame`
#         regardless, use the ``chunksize`` or ``iterator`` parameter to return the data in
#         chunks. (Only valid with C parser).
#     memory_map : bool, default False
#         If a filepath is provided for ``filepath_or_buffer``, map the file object
#         directly onto memory and access the data directly from there. Using this
#         option can improve performance because there is no longer any I/O overhead.
#     float_precision : {'high', 'legacy', 'round_trip'}, optional
#         Specifies which converter the C engine should use for floating-point
#         values. The options are ``None`` or ``'high'`` for the ordinary converter,
#         ``'legacy'`` for the original lower precision pandas converter, and
#         ``'round_trip'`` for the round-trip converter.
#
#     storage_options : dict, optional
#         Extra options that make sense for a particular storage connection, e.g.
#         host, port, username, password, etc. For HTTP(S) URLs the key-value pairs
#         are forwarded to ``urllib.request.Request`` as header options. For other
#         URLs (e.g. starting with "s3://", and "gcs://") the key-value pairs are
#         forwarded to ``fsspec.open``. Please see ``fsspec`` and ``urllib`` for more
#         details, and for more examples on storage options refer `here
#         <https://pandas.pydata.org/docs/user_guide/io.html?
#         highlight=storage_options#reading-writing-remote-files>`_.
#
#     dtype_backend : {'numpy_nullable', 'pyarrow'}, default 'numpy_nullable'
#         Back-end data type applied to the resultant :class:`DataFrame`
#         (still experimental). Behaviour is as follows:
#
#         * ``"numpy_nullable"``: returns nullable-dtype-backed :class:`DataFrame`
#           (default).
#         * ``"pyarrow"``: returns pyarrow-backed nullable :class:`ArrowDtype`
#           DataFrame.
#
#         .. versionadded:: 2.0
#
#     Returns
#     -------
#     DataFrame or TextFileReader
#         A comma-separated values (csv) file is returned as two-dimensional
#         data structure with labeled axes.
#
#     See Also
#     --------
#     DataFrame.to_csv : Write DataFrame to a comma-separated values (csv) file.
#     read_table : Read general delimited file into DataFrame.
#     read_fwf : Read a table of fixed-width formatted lines into DataFrame.
#
#     Examples
#     --------
#     >>> pd.read_csv('data.csv')  # doctest: +SKIP

# %% [markdown]
# On va maintenant pouvoir importer notre base de données. En général on importe des données CSV (comma separated values), des bases de données compressées en collant toutes les cellules d'une ligne et en les séparant par des virgules ou points-virgules.
# Attention !!! Quelques problèmes fréquents :
# 1) Un fichier CSV peut avoir comme séparateur la virgule, le point-virgule ou plus rarement la tabulation. Si on n'arrive pas à ouvrir sa base de données on peut vérifier si le problème vient de là. Si oui, on peut rajouter l'argument sep = "..." (par exemple si dans notre fichier le séparateur est un point-virgule sep = ";")
# 2) L'encodage est un problème que l'on rencontre fréquemment si la base de données contient des accents ou des caractères latins. On doit alors vérifier que python importe bien la base dans le format "UTF-8" et que notre base est bien codée dans ce format. Si elle ne l'est pas on peut régler le problème avec Excel.
#
# Ici on importe une base de données Excel parce que c'est le format natif du baromètre du numérique. La fonction est un peu différente, c'est read_excel de pandas.

# %%
#On importe le baromètre du numérique (ici il faut trouver le bon lien=)
df = pd.read_excel("barometre-du-numerique-2023.xlsx")

# %% [markdown]
# Quelques fonctions utiles pour examiner rapidement les principales caractéristiques de notre base de données :
# 1) head : imprime les premières lignes du jeu de données (on peut lui indiquer entre parenthèses combien) (nb : ici la base est constituée d'un jeu de données donc les deux termes sont un peu rendondants)
# 2) shape : imprime le nombre de lignes et de colonnes
# 3) info : imprime le nombre de ligness, de colonnes et quelques autres informations (taille de l'objet, nombre de variable quantitatives, ...)
# 4) describe : imprime des informations de base sur les variables quantitatives de la base : somme, moyenne, écart-type, minimum, ...
# 5) values : imprime les différentes modalités des variables catégorielles
# 6) columns: imprime le nom des colonnes du jeu de données

# %%
df.head(3)
print(df.shape)
print(df.info())
print(df.describe())
print(df.values)
print(df.columns)
# Out:
# (4284, 263)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4284 entries, 0 to 4283
# Columns: 263 entries, ANNEENQ to REV_TR7
# dtypes: float64(25), int64(4), object(234)
# memory usage: 8.6+ MB
# None
#        ANNEENQ         POND       NBPERS       NBTIC1       NBTIC2  \
# count   4284.0  4284.000000  4284.000000  4279.000000  4280.000000
# mean    2023.0     1.000000     2.430906     2.056088     1.592056
# std        0.0     0.543657     1.343132     1.583173     1.222953
# min     2023.0     0.290337     1.000000     0.000000     0.000000
# 25%     2023.0     0.624133     1.000000     1.000000     1.000000
# 50%     2023.0     0.874689     2.000000     2.000000     1.000000
# 75%     2023.0     1.186910     3.000000     3.000000     2.000000
# max     2023.0     3.463192    12.000000    15.000000    15.000000
#
#             NBTIC3       NBTIC5  NBTIC5_NOWEB       NBTIC6  NBTIC6_NOWEB  ...  \
# count  4279.000000  3678.000000   3427.000000  3680.000000   3429.000000  ...
# mean      0.814209     0.680533      0.669098     1.568478      1.601925  ...
# std       1.239193     1.179974      1.136452     1.365591      1.360986  ...
# min       0.000000     0.000000      0.000000     0.000000      0.000000  ...
# 25%       0.000000     0.000000      0.000000     1.000000      1.000000  ...
# 50%       1.000000     0.000000      0.000000     1.000000      1.000000  ...
# 75%       1.000000     1.000000      1.000000     2.000000      2.000000  ...
# max      15.000000    15.000000     15.000000    15.000000     15.000000  ...
#
#        NBOLD5_NOWEB       NBOLD6  NBOLD6_NOWEB       NBOLD7  NBOLD7_NOWEB  \
# count   3416.000000  3671.000000   3421.000000  3664.000000   3415.000000
# mean       0.288056     0.429038      0.408360     0.236081      0.219912
# std        0.837719     0.991691      0.947221     0.838077      0.790958
# min        0.000000     0.000000      0.000000     0.000000      0.000000
# 25%        0.000000     0.000000      0.000000     0.000000      0.000000
# 50%        0.000000     0.000000      0.000000     0.000000      0.000000
# 75%        0.000000     1.000000      1.000000     0.000000      0.000000
# max       15.000000    15.000000     15.000000    15.000000     15.000000
#
#               IDENT   ANNEE  NBTIC1_NOWEB  NBTIC2_NOWEB  NBTIC3_NOWEB
# count  4.284000e+03  4284.0   3427.000000   3428.000000   3427.000000
# mean   9.368195e+13  2023.0      2.255909      1.684072      0.930843
# std    8.933996e+13     0.0      1.563276      1.253516      1.277883
# min    2.023000e+13  2023.0      0.000000      0.000000      0.000000
# 25%    2.023180e+13  2023.0      1.000000      1.000000      0.000000
# 50%    2.023710e+13  2023.0      2.000000      1.000000      1.000000
# 75%    2.023170e+14  2023.0      3.000000      2.000000      1.000000
# max    2.023760e+14  2023.0     15.000000     15.000000     15.000000
#
# [8 rows x 29 columns]
# [[2023 'CAWI' 0.738586741 ... 'Oui, en raison du prix' 'Non'
#   'De 1500 à 2300 euros']
#  [2023 'CAWI' 0.812827827 ... 'Non' 'Non' 'De 1500 à 2300 euros']
#  [2023 'CAWI' 0.642614593 ... 'Non' 'Non' 'De 900 à 1500 euros']
#  ...
#  [2023 'CATI' 0.919837338 ... 'Non' 'Non' 'De 1500 à 2300 euros']
#  [2023 'CATI' 0.772284211 ... 'Non' 'Non' 'De 2300 à 3100 euros']
#  [2023 'CATI' 0.474186803 ... 'Non' 'Non' 'De 1500 à 2300 euros']]
# Index(['ANNEENQ', 'RECUEIL', 'POND', 'AGE6FUZ', 'AGGLO5', 'REGION', 'TYPLOG',
#        'TYPLOG2', 'NBPERS', 'NBPERS5',
#        ...
#        'ENV5', 'ENV6', 'ENV7', 'ENV8', 'ENV9', 'ENV10', 'ENV11', 'ENV6EXP_1',
#        'ENV6EXP_2', 'REV_TR7'],
#       dtype='object', length=263)

# %% [markdown]
# On peut ensuite classer les lignes/individus en fonction des valeurs d'une ou de plusieurs variables. Attention, on ne trie pas qu'une seule colonne avec sort_values (d'ailleurs c'est peu utile), on trie toutes les colonnes. On choisit aussi si on trie paar ordre croissant ou décroissant avec ascending = [True] pour croissant et ascending = [False] pour décroissant.

# %%
#On trie les individus par ordre décroissant du nombre de personnes dans leur foyer
df.sort_values(['NBPERS'], ascending = [False])
# Out:
#       ANNEENQ RECUEIL      POND         AGE6FUZ                     AGGLO5  \
# 1994     2023    CAWI  0.632694       60-69 ans           Communes rurales
# 3138     2023    CAWI  0.359479       18-24 ans  100 000 habitants et plus
# 3453     2023    CAWI  0.683777       18-24 ans   2 000 à 19 999 habitants
# 3592     2023    CAWI  2.514056       12-17 ans   Agglomération parisienne
# 3134     2023    CAWI  0.633847       40-59 ans   2 000 à 19 999 habitants
# ...       ...     ...       ...             ...                        ...
# 2076     2023    CAWI  1.267874       40-59 ans  100 000 habitants et plus
# 2072     2023    CAWI  0.734740       40-59 ans  100 000 habitants et plus
# 2065     2023    CAWI  0.397577  70 ans et plus  100 000 habitants et plus
# 2063     2023    CAWI  0.593318  70 ans et plus  20 000 à 99 999 habitants
# 4283     2023    CATI  0.474187  70 ans et plus   2 000 à 19 999 habitants
#
#                       REGION  \
# 1994               Normandie
# 3138               Occitanie
# 3453                Bretagne
# 3592           Ile de France
# 3134               Grand Est
# ...                      ...
# 2076  Auvergne - Rhône Alpes
# 2072        Pays de la Loire
# 2065               Occitanie
# 2063         Hauts de France
# 4283                   Corse
#
#                                                  TYPLOG              TYPLOG2  \
# 1994                                             Maison  Maison individuelle
# 3138  Autre (chambre d’hôtel, centre d’hébergement e...   Logement collectif
# 3453                                             Maison  Maison individuelle
# 3592                                        Appartement   Logement collectif
# 3134  Autre (chambre d’hôtel, centre d’hébergement e...   Logement collectif
# ...                                                 ...                  ...
# 2076                                        Appartement   Logement collectif
# 2072                                        Appartement   Logement collectif
# 2065                                             Maison  Maison individuelle
# 2063                                             Maison  Maison individuelle
# 4283                                             Maison  Maison individuelle
#
#       NBPERS                 NBPERS5  ...  \
# 1994      12  Cinq personnes et plus  ...
# 3138      10  Cinq personnes et plus  ...
# 3453       9  Cinq personnes et plus  ...
# 3592       9  Cinq personnes et plus  ...
# 3134       8  Cinq personnes et plus  ...
# ...      ...                     ...  ...
# 2076       1            Une personne  ...
# 2072       1            Une personne  ...
# 2065       1            Une personne  ...
# 2063       1            Une personne  ...
# 4283       1            Une personne  ...
#
#                                                    ENV5  \
# 1994  Je ne le fais pas et je ne compte pas le faire...
# 3138                                        ne sait pas
# 3453                                        ne sait pas
# 3592  Je ne le fais pas mais je compte le faire à l’...
# 3134  Je ne le fais pas et je ne compte pas le faire...
# ...                                                 ...
# 2076  Je ne le fais pas mais je compte le faire à l’...
# 2072                                Oui je le fais déjà
# 2065  Je ne le fais pas et je ne compte pas le faire...
# 2063                                Oui je le fais déjà
# 4283                                                NaN
#
#                                                    ENV6  \
# 1994  Je ne le fais pas mais je compte le faire à l’...
# 3138                                        ne sait pas
# 3453                                        ne sait pas
# 3592                                Oui je le fais déjà
# 3134  Je ne le fais pas et je ne compte pas le faire...
# ...                                                 ...
# 2076  Je ne le fais pas mais je compte le faire à l’...
# 2072  Je ne le fais pas et je ne compte pas le faire...
# 2065  Je ne le fais pas mais je compte le faire à l’...
# 2063                                        ne sait pas
# 4283                                                NaN
#
#                                                    ENV7  \
# 1994  Je ne le fais pas mais je compte le faire à l’...
# 3138                                        ne sait pas
# 3453                                        ne sait pas
# 3592  Je ne le fais pas mais je compte le faire à l’...
# 3134  Je ne le fais pas et je ne compte pas le faire...
# ...                                                 ...
# 2076  Je ne le fais pas mais je compte le faire à l’...
# 2072                                Oui je le fais déjà
# 2065                                Oui je le fais déjà
# 2063                                Oui je le fais déjà
# 4283                                                NaN
#
#                                                    ENV8  \
# 1994  Je ne le fais pas mais je compte le faire à l’...
# 3138                                        ne sait pas
# 3453                                        ne sait pas
# 3592                                Oui je le fais déjà
# 3134  Je ne le fais pas et je ne compte pas le faire...
# ...                                                 ...
# 2076                                Oui je le fais déjà
# 2072                                Oui je le fais déjà
# 2065  Je ne le fais pas et je ne compte pas le faire...
# 2063                                Oui je le fais déjà
# 4283                                                NaN
#
#                                                    ENV9  \
# 1994  Je ne le fais pas et je ne compte pas le faire...
# 3138                                        ne sait pas
# 3453                                        ne sait pas
# 3592                                Oui je le fais déjà
# 3134  Je ne le fais pas et je ne compte pas le faire...
# ...                                                 ...
# 2076  Je ne le fais pas mais je compte le faire à l’...
# 2072                                Oui je le fais déjà
# 2065                                Oui je le fais déjà
# 2063                                Oui je le fais déjà
# 4283                                                NaN
#
#                                                   ENV10  \
# 1994  Je ne le fais pas mais je compte le faire à l’...
# 3138                                        ne sait pas
# 3453                                        ne sait pas
# 3592                                Oui je le fais déjà
# 3134  Je ne le fais pas et je ne compte pas le faire...
# ...                                                 ...
# 2076                                Oui je le fais déjà
# 2072  Je ne le fais pas mais je compte le faire à l’...
# 2065                                Oui je le fais déjà
# 2063                                Oui je le fais déjà
# 4283                                                NaN
#
#                                                   ENV11  \
# 1994  Je ne le fais pas mais je compte le faire à l’...
# 3138                                        ne sait pas
# 3453                                        ne sait pas
# 3592                                Oui je le fais déjà
# 3134  Je ne le fais pas et je ne compte pas le faire...
# ...                                                 ...
# 2076  Je ne le fais pas mais je compte le faire à l’...
# 2072  Je ne le fais pas mais je compte le faire à l’...
# 2065                                Oui je le fais déjà
# 2063                                Oui je le fais déjà
# 4283                                                NaN
#
#                                     ENV6EXP_1  \
# 1994  Oui, pour des raisons environnementales
# 3138                                      Non
# 3453                                      Non
# 3592                   Oui, en raison du prix
# 3134                                      Non
# ...                                       ...
# 2076                                      Non
# 2072                                      Non
# 2065                                      Non
# 2063                                      Non
# 4283                                      Non
#
#                                     ENV6EXP_2  \
# 1994  Oui, pour des raisons environnementales
# 3138                                      Non
# 3453                                      Non
# 3592                   Oui, en raison du prix
# 3134                                      Non
# ...                                       ...
# 2076                                      Non
# 2072                                      Non
# 2065                                      Non
# 2063                                      Non
# 4283                                      Non
#
#                                REV_TR7
# 1994               De 900 à 1500 euros
# 3138  Non déclaré (ne sait pas, refus)
# 3453                 3100 à 4000 euros
# 3592  Non déclaré (ne sait pas, refus)
# 3134                4000 euros et plus
# ...                                ...
# 2076              De 1500 à 2300 euros
# 2072              De 1500 à 2300 euros
# 2065              De 2300 à 3100 euros
# 2063               De 900 à 1500 euros
# 4283              De 1500 à 2300 euros
#
# [4284 rows x 263 columns]

# %% [markdown]
# On peut faire de même mais avec plusieurs variables de classement.

# %%
#On trie les individus par ordre décroissant du nombre de personnes dans leur foyer 
#et à nombre de personnes égales par type de logement. 
df.sort_values(['NBPERS', 'TYPLOG'], ascending = [False, True])
# Out:
#       ANNEENQ RECUEIL      POND         AGE6FUZ                     AGGLO5  \
# 1994     2023    CAWI  0.632694       60-69 ans           Communes rurales
# 3138     2023    CAWI  0.359479       18-24 ans  100 000 habitants et plus
# 3592     2023    CAWI  2.514056       12-17 ans   Agglomération parisienne
# 3453     2023    CAWI  0.683777       18-24 ans   2 000 à 19 999 habitants
# 3134     2023    CAWI  0.633847       40-59 ans   2 000 à 19 999 habitants
# ...       ...     ...       ...             ...                        ...
# 4269     2023    CATI  0.550397  70 ans et plus           Communes rurales
# 4273     2023    CATI  0.783189  70 ans et plus   Agglomération parisienne
# 4275     2023    CATI  0.396232  70 ans et plus  100 000 habitants et plus
# 4280     2023    CATI  0.452893       40-59 ans  100 000 habitants et plus
# 4283     2023    CATI  0.474187  70 ans et plus   2 000 à 19 999 habitants
#
#                   REGION                                             TYPLOG  \
# 1994           Normandie                                             Maison
# 3138           Occitanie  Autre (chambre d’hôtel, centre d’hébergement e...
# 3592       Ile de France                                        Appartement
# 3453            Bretagne                                             Maison
# 3134           Grand Est  Autre (chambre d’hôtel, centre d’hébergement e...
# ...                  ...                                                ...
# 4269  Nouvelle Aquitaine                                             Maison
# 4273       Ile de France                                             Maison
# 4275                PACA                                             Maison
# 4280    Pays de la Loire                                             Maison
# 4283               Corse                                             Maison
#
#                   TYPLOG2  NBPERS                 NBPERS5  ...  \
# 1994  Maison individuelle      12  Cinq personnes et plus  ...
# 3138   Logement collectif      10  Cinq personnes et plus  ...
# 3592   Logement collectif       9  Cinq personnes et plus  ...
# 3453  Maison individuelle       9  Cinq personnes et plus  ...
# 3134   Logement collectif       8  Cinq personnes et plus  ...
# ...                   ...     ...                     ...  ...
# 4269  Maison individuelle       1            Une personne  ...
# 4273  Maison individuelle       1            Une personne  ...
# 4275  Maison individuelle       1            Une personne  ...
# 4280  Maison individuelle       1            Une personne  ...
# 4283  Maison individuelle       1            Une personne  ...
#
#                                                    ENV5  \
# 1994  Je ne le fais pas et je ne compte pas le faire...
# 3138                                        ne sait pas
# 3592  Je ne le fais pas mais je compte le faire à l’...
# 3453                                        ne sait pas
# 3134  Je ne le fais pas et je ne compte pas le faire...
# ...                                                 ...
# 4269                                                NaN
# 4273                                                NaN
# 4275                                                NaN
# 4280                                                NaN
# 4283                                                NaN
#
#                                                    ENV6  \
# 1994  Je ne le fais pas mais je compte le faire à l’...
# 3138                                        ne sait pas
# 3592                                Oui je le fais déjà
# 3453                                        ne sait pas
# 3134  Je ne le fais pas et je ne compte pas le faire...
# ...                                                 ...
# 4269                                                NaN
# 4273                                                NaN
# 4275                                                NaN
# 4280                                                NaN
# 4283                                                NaN
#
#                                                    ENV7  \
# 1994  Je ne le fais pas mais je compte le faire à l’...
# 3138                                        ne sait pas
# 3592  Je ne le fais pas mais je compte le faire à l’...
# 3453                                        ne sait pas
# 3134  Je ne le fais pas et je ne compte pas le faire...
# ...                                                 ...
# 4269                                                NaN
# 4273                                                NaN
# 4275                                                NaN
# 4280                                                NaN
# 4283                                                NaN
#
#                                                    ENV8  \
# 1994  Je ne le fais pas mais je compte le faire à l’...
# 3138                                        ne sait pas
# 3592                                Oui je le fais déjà
# 3453                                        ne sait pas
# 3134  Je ne le fais pas et je ne compte pas le faire...
# ...                                                 ...
# 4269                                                NaN
# 4273                                                NaN
# 4275                                                NaN
# 4280                                                NaN
# 4283                                                NaN
#
#                                                    ENV9  \
# 1994  Je ne le fais pas et je ne compte pas le faire...
# 3138                                        ne sait pas
# 3592                                Oui je le fais déjà
# 3453                                        ne sait pas
# 3134  Je ne le fais pas et je ne compte pas le faire...
# ...                                                 ...
# 4269                                                NaN
# 4273                                                NaN
# 4275                                                NaN
# 4280                                                NaN
# 4283                                                NaN
#
#                                                   ENV10  \
# 1994  Je ne le fais pas mais je compte le faire à l’...
# 3138                                        ne sait pas
# 3592                                Oui je le fais déjà
# 3453                                        ne sait pas
# 3134  Je ne le fais pas et je ne compte pas le faire...
# ...                                                 ...
# 4269                                                NaN
# 4273                                                NaN
# 4275                                                NaN
# 4280                                                NaN
# 4283                                                NaN
#
#                                                   ENV11  \
# 1994  Je ne le fais pas mais je compte le faire à l’...
# 3138                                        ne sait pas
# 3592                                Oui je le fais déjà
# 3453                                        ne sait pas
# 3134  Je ne le fais pas et je ne compte pas le faire...
# ...                                                 ...
# 4269                                                NaN
# 4273                                                NaN
# 4275                                                NaN
# 4280                                                NaN
# 4283                                                NaN
#
#                                     ENV6EXP_1  \
# 1994  Oui, pour des raisons environnementales
# 3138                                      Non
# 3592                   Oui, en raison du prix
# 3453                                      Non
# 3134                                      Non
# ...                                       ...
# 4269                                      Non
# 4273                                      Non
# 4275                                      Non
# 4280                                      Non
# 4283                                      Non
#
#                                     ENV6EXP_2  \
# 1994  Oui, pour des raisons environnementales
# 3138                                      Non
# 3592                   Oui, en raison du prix
# 3453                                      Non
# 3134                                      Non
# ...                                       ...
# 4269                                      Non
# 4273                                      Non
# 4275                                      Non
# 4280                                      Non
# 4283                                      Non
#
#                                REV_TR7
# 1994               De 900 à 1500 euros
# 3138  Non déclaré (ne sait pas, refus)
# 3592  Non déclaré (ne sait pas, refus)
# 3453                 3100 à 4000 euros
# 3134                4000 euros et plus
# ...                                ...
# 4269               De 900 à 1500 euros
# 4273               De 900 à 1500 euros
# 4275                 3100 à 4000 euros
# 4280  Non déclaré (ne sait pas, refus)
# 4283              De 1500 à 2300 euros
#
# [4284 rows x 263 columns]

# %% [markdown]
# Attention, si on trie selon une variable catégorielle, par défaut on obtiendra un  tri par ordre alphabétique. Cependant on peut définir l'ordre des modalités manuellement.

# %%
df["TYPLOG"] = df["TYPLOG"].astype('category')
df["TYPLOG"].cat.reorder_categories(["Maison", "Appartement", "Autre (chambre d’hôtel, centre d’hébergement etc.)"])
df.sort_values(['TYPLOG'], ascending = [False])
# Out:
#       ANNEENQ RECUEIL      POND    AGE6FUZ                     AGGLO5  \
# 2142     2023    CAWI  0.445438  18-24 ans   Agglomération parisienne
# 2587     2023    CAWI  0.983223  40-59 ans  100 000 habitants et plus
# 2555     2023    CAWI  1.154502  25-39 ans           Communes rurales
# 2556     2023    CAWI  1.000505  18-24 ans   Agglomération parisienne
# 2559     2023    CAWI  0.705901  25-39 ans  100 000 habitants et plus
# ...       ...     ...       ...        ...                        ...
# 2710     2023    CAWI  0.763187  60-69 ans  100 000 habitants et plus
# 2709     2023    CAWI  1.663803  60-69 ans   2 000 à 19 999 habitants
# 2705     2023    CAWI  0.956464  25-39 ans   Agglomération parisienne
# 2704     2023    CAWI  0.893942  40-59 ans   Agglomération parisienne
# 0        2023    CAWI  0.738587  25-39 ans   Agglomération parisienne
#
#                   REGION       TYPLOG              TYPLOG2  NBPERS  \
# 2142       Ile de France       Maison  Maison individuelle       5
# 2587           Grand Est       Maison  Maison individuelle       3
# 2555           Normandie       Maison  Maison individuelle       4
# 2556       Ile de France       Maison  Maison individuelle       2
# 2559  Nouvelle Aquitaine       Maison  Maison individuelle       1
# ...                  ...          ...                  ...     ...
# 2710            Bretagne  Appartement   Logement collectif       1
# 2709           Grand Est  Appartement   Logement collectif       6
# 2705       Ile de France  Appartement   Logement collectif       5
# 2704       Ile de France  Appartement   Logement collectif       4
# 0          Ile de France  Appartement   Logement collectif       1
#
#                      NBPERS5  ...  \
# 2142  Cinq personnes et plus  ...
# 2587         Trois personnes  ...
# 2555        Quatre personnes  ...
# 2556          Deux personnes  ...
# 2559            Une personne  ...
# ...                      ...  ...
# 2710            Une personne  ...
# 2709  Cinq personnes et plus  ...
# 2705  Cinq personnes et plus  ...
# 2704        Quatre personnes  ...
# 0               Une personne  ...
#
#                                                    ENV5  \
# 2142  Je ne le fais pas et je ne compte pas le faire...
# 2587  Je ne le fais pas mais je compte le faire à l’...
# 2555                                Oui je le fais déjà
# 2556  Je ne le fais pas mais je compte le faire à l’...
# 2559  Je ne le fais pas mais je compte le faire à l’...
# ...                                                 ...
# 2710  Je ne le fais pas et je ne compte pas le faire...
# 2709                                Oui je le fais déjà
# 2705                                Oui je le fais déjà
# 2704                                Oui je le fais déjà
# 0     Je ne le fais pas et je ne compte pas le faire...
#
#                                                    ENV6  \
# 2142  Je ne le fais pas et je ne compte pas le faire...
# 2587  Je ne le fais pas mais je compte le faire à l’...
# 2555  Je ne le fais pas et je ne compte pas le faire...
# 2556  Je ne le fais pas mais je compte le faire à l’...
# 2559  Je ne le fais pas et je ne compte pas le faire...
# ...                                                 ...
# 2710                                        ne sait pas
# 2709  Je ne le fais pas mais je compte le faire à l’...
# 2705                                Oui je le fais déjà
# 2704  Je ne le fais pas mais je compte le faire à l’...
# 0                                   Oui je le fais déjà
#
#                                                    ENV7  \
# 2142  Je ne le fais pas et je ne compte pas le faire...
# 2587  Je ne le fais pas mais je compte le faire à l’...
# 2555  Je ne le fais pas et je ne compte pas le faire...
# 2556  Je ne le fais pas mais je compte le faire à l’...
# 2559  Je ne le fais pas et je ne compte pas le faire...
# ...                                                 ...
# 2710  Je ne le fais pas mais je compte le faire à l’...
# 2709                                Oui je le fais déjà
# 2705                                Oui je le fais déjà
# 2704  Je ne le fais pas mais je compte le faire à l’...
# 0     Je ne le fais pas et je ne compte pas le faire...
#
#                                                    ENV8  \
# 2142  Je ne le fais pas mais je compte le faire à l’...
# 2587  Je ne le fais pas mais je compte le faire à l’...
# 2555  Je ne le fais pas et je ne compte pas le faire...
# 2556  Je ne le fais pas mais je compte le faire à l’...
# 2559  Je ne le fais pas mais je compte le faire à l’...
# ...                                                 ...
# 2710  Je ne le fais pas et je ne compte pas le faire...
# 2709                                Oui je le fais déjà
# 2705  Je ne le fais pas et je ne compte pas le faire...
# 2704                                Oui je le fais déjà
# 0     Je ne le fais pas et je ne compte pas le faire...
#
#                                                    ENV9  \
# 2142  Je ne le fais pas mais je compte le faire à l’...
# 2587  Je ne le fais pas mais je compte le faire à l’...
# 2555  Je ne le fais pas et je ne compte pas le faire...
# 2556  Je ne le fais pas mais je compte le faire à l’...
# 2559  Je ne le fais pas mais je compte le faire à l’...
# ...                                                 ...
# 2710                                Oui je le fais déjà
# 2709                                Oui je le fais déjà
# 2705  Je ne le fais pas et je ne compte pas le faire...
# 2704  Je ne le fais pas et je ne compte pas le faire...
# 0     Je ne le fais pas et je ne compte pas le faire...
#
#                                                   ENV10  \
# 2142  Je ne le fais pas mais je compte le faire à l’...
# 2587  Je ne le fais pas mais je compte le faire à l’...
# 2555  Je ne le fais pas mais je compte le faire à l’...
# 2556                                Oui je le fais déjà
# 2559  Je ne le fais pas mais je compte le faire à l’...
# ...                                                 ...
# 2710                                Oui je le fais déjà
# 2709                                Oui je le fais déjà
# 2705                                Oui je le fais déjà
# 2704                                Oui je le fais déjà
# 0     Je ne le fais pas mais je compte le faire à l’...
#
#                                                   ENV11  \
# 2142  Je ne le fais pas mais je compte le faire à l’...
# 2587                                Oui je le fais déjà
# 2555  Je ne le fais pas mais je compte le faire à l’...
# 2556                                Oui je le fais déjà
# 2559                                Oui je le fais déjà
# ...                                                 ...
# 2710  Je ne le fais pas et je ne compte pas le faire...
# 2709                                Oui je le fais déjà
# 2705                                Oui je le fais déjà
# 2704  Je ne le fais pas mais je compte le faire à l’...
# 0     Je ne le fais pas et je ne compte pas le faire...
#
#                                     ENV6EXP_1  \
# 2142  Oui, pour des raisons environnementales
# 2587                                      Non
# 2555                   Oui, en raison du prix
# 2556  Oui, pour des raisons environnementales
# 2559  Oui, pour des raisons environnementales
# ...                                       ...
# 2710                                      Non
# 2709                                      Non
# 2705                   Oui, en raison du prix
# 2704                                      Non
# 0                      Oui, en raison du prix
#
#                                     ENV6EXP_2               REV_TR7
# 2142                Oui, pour d’autres raison    Moins de 900 euros
# 2587                                      Non  De 2300 à 3100 euros
# 2555                                      Non    4000 euros et plus
# 2556                Oui, pour d’autres raison  De 1500 à 2300 euros
# 2559  Oui, pour des raisons environnementales  De 1500 à 2300 euros
# ...                                       ...                   ...
# 2710                                      Non    Moins de 900 euros
# 2709                                      Non    4000 euros et plus
# 2705                   Oui, en raison du prix  De 2300 à 3100 euros
# 2704                   Oui, en raison du prix    4000 euros et plus
# 0                                         Non  De 1500 à 2300 euros
#
# [4284 rows x 263 columns]

# %% [markdown]
# On peut aussi choisir de filtrer pour n'afficher que certaines parties d'un jeu de données. Voire définir de nouveaux objets qui contiendront une version filtrée de ce jeu de données. Si l'on n'affiche qu'une variable on met son nom entre crochets et si l'on veut en afficher deux ou plus c'est deux fois entre crochets.

# %%
df["REGION"]
df[["REGION", "TYPLOG"]]
# Out:
#                   REGION       TYPLOG
# 0          Ile de France  Appartement
# 1          Ile de France       Maison
# 2               Bretagne       Maison
# 3                   PACA       Maison
# 4     Nouvelle Aquitaine  Appartement
# ...                  ...          ...
# 4279           Grand Est       Maison
# 4280    Pays de la Loire       Maison
# 4281     Hauts de France       Maison
# 4282       Ile de France  Appartement
# 4283               Corse       Maison
#
# [4284 rows x 2 columns]

# %% [markdown]
# On peut aussi vérifier pour quels individus une condition est vraie. Que ce soit pour une variable quantitative ou qualitative.

# %%
df["NBPERS"] > 10
df[df["TYPLOG"] == "Maison"]
# Out:
#       ANNEENQ RECUEIL      POND         AGE6FUZ                     AGGLO5  \
# 1        2023    CAWI  0.812828       25-39 ans  20 000 à 99 999 habitants
# 2        2023    CAWI  0.642615       25-39 ans           Communes rurales
# 3        2023    CAWI  1.099717       25-39 ans  100 000 habitants et plus
# 6        2023    CAWI  1.132278       40-59 ans  100 000 habitants et plus
# 7        2023    CAWI  0.374290  70 ans et plus           Communes rurales
# ...       ...     ...       ...             ...                        ...
# 4277     2023    CATI  0.884965       40-59 ans           Communes rurales
# 4279     2023    CATI  0.807913  70 ans et plus           Communes rurales
# 4280     2023    CATI  0.452893       40-59 ans  100 000 habitants et plus
# 4281     2023    CATI  0.919837       40-59 ans           Communes rurales
# 4283     2023    CATI  0.474187  70 ans et plus   2 000 à 19 999 habitants
#
#                       REGION  TYPLOG              TYPLOG2  NBPERS  \
# 1              Ile de France  Maison  Maison individuelle       2
# 2                   Bretagne  Maison  Maison individuelle       1
# 3                       PACA  Maison  Maison individuelle       5
# 6           Pays de la Loire  Maison  Maison individuelle       4
# 7     Auvergne - Rhône Alpes  Maison  Maison individuelle       1
# ...                      ...     ...                  ...     ...
# 4277  Auvergne - Rhône Alpes  Maison  Maison individuelle       2
# 4279               Grand Est  Maison  Maison individuelle       2
# 4280        Pays de la Loire  Maison  Maison individuelle       1
# 4281         Hauts de France  Maison  Maison individuelle       3
# 4283                   Corse  Maison  Maison individuelle       1
#
#                      NBPERS5  ...  \
# 1             Deux personnes  ...
# 2               Une personne  ...
# 3     Cinq personnes et plus  ...
# 6           Quatre personnes  ...
# 7               Une personne  ...
# ...                      ...  ...
# 4277          Deux personnes  ...
# 4279          Deux personnes  ...
# 4280            Une personne  ...
# 4281         Trois personnes  ...
# 4283            Une personne  ...
#
#                                                    ENV5  \
# 1                                   Oui je le fais déjà
# 2                                   Oui je le fais déjà
# 3     Je ne le fais pas mais je compte le faire à l’...
# 6     Je ne le fais pas mais je compte le faire à l’...
# 7     Je ne le fais pas mais je compte le faire à l’...
# ...                                                 ...
# 4277                                                NaN
# 4279                                                NaN
# 4280                                                NaN
# 4281                                                NaN
# 4283                                                NaN
#
#                                                    ENV6  \
# 1     Je ne le fais pas et je ne compte pas le faire...
# 2     Je ne le fais pas mais je compte le faire à l’...
# 3     Je ne le fais pas mais je compte le faire à l’...
# 6     Je ne le fais pas et je ne compte pas le faire...
# 7     Je ne le fais pas et je ne compte pas le faire...
# ...                                                 ...
# 4277                                                NaN
# 4279                                                NaN
# 4280                                                NaN
# 4281                                                NaN
# 4283                                                NaN
#
#                                                    ENV7  \
# 1     Je ne le fais pas et je ne compte pas le faire...
# 2     Je ne le fais pas mais je compte le faire à l’...
# 3     Je ne le fais pas mais je compte le faire à l’...
# 6                                   Oui je le fais déjà
# 7     Je ne le fais pas mais je compte le faire à l’...
# ...                                                 ...
# 4277                                                NaN
# 4279                                                NaN
# 4280                                                NaN
# 4281                                                NaN
# 4283                                                NaN
#
#                                                    ENV8  \
# 1     Je ne le fais pas et je ne compte pas le faire...
# 2     Je ne le fais pas mais je compte le faire à l’...
# 3     Je ne le fais pas mais je compte le faire à l’...
# 6     Je ne le fais pas et je ne compte pas le faire...
# 7     Je ne le fais pas mais je compte le faire à l’...
# ...                                                 ...
# 4277                                                NaN
# 4279                                                NaN
# 4280                                                NaN
# 4281                                                NaN
# 4283                                                NaN
#
#                                                    ENV9  \
# 1                                           ne sait pas
# 2                                   Oui je le fais déjà
# 3     Je ne le fais pas mais je compte le faire à l’...
# 6                                   Oui je le fais déjà
# 7     Je ne le fais pas mais je compte le faire à l’...
# ...                                                 ...
# 4277                                                NaN
# 4279                                                NaN
# 4280                                                NaN
# 4281                                                NaN
# 4283                                                NaN
#
#                                                   ENV10  \
# 1                                   Oui je le fais déjà
# 2                                   Oui je le fais déjà
# 3     Je ne le fais pas mais je compte le faire à l’...
# 6     Je ne le fais pas mais je compte le faire à l’...
# 7                                   Oui je le fais déjà
# ...                                                 ...
# 4277                                                NaN
# 4279                                                NaN
# 4280                                                NaN
# 4281                                                NaN
# 4283                                                NaN
#
#                                                   ENV11 ENV6EXP_1  \
# 1                                           ne sait pas       Non
# 2     Je ne le fais pas mais je compte le faire à l’...       Non
# 3     Je ne le fais pas mais je compte le faire à l’...       Non
# 6     Je ne le fais pas mais je compte le faire à l’...       Non
# 7                                   Oui je le fais déjà       Non
# ...                                                 ...       ...
# 4277                                                NaN       Non
# 4279                                                NaN       Non
# 4280                                                NaN       Non
# 4281                                                NaN       Non
# 4283                                                NaN       Non
#
#                    ENV6EXP_2                           REV_TR7
# 1                        Non              De 1500 à 2300 euros
# 2                        Non               De 900 à 1500 euros
# 3                        Non              De 1500 à 2300 euros
# 6                        Non                4000 euros et plus
# 7                        Non              De 2300 à 3100 euros
# ...                      ...                               ...
# 4277  Oui, en raison du prix              De 1500 à 2300 euros
# 4279                     Non               De 900 à 1500 euros
# 4280                     Non  Non déclaré (ne sait pas, refus)
# 4281                     Non              De 1500 à 2300 euros
# 4283                     Non              De 1500 à 2300 euros
#
# [2635 rows x 263 columns]

# %% [markdown]
# Mais on peut aussi filtrer en faisant des opérations sur le jeu de données

# %%
fam_nombreuses = df[df["NBPERS"] > 10]
fam_nombreuses_appart = df[(df["NBPERS"] > 5) & (df["TYPLOG"] == "Appartement")]
fam_nombreuses_ou_appart = df[(df["NBPERS"] > 10) | (df["TYPLOG"] == "Appartement")]
fam_nombreuses.head(3)
# Out:
#       ANNEENQ RECUEIL      POND    AGE6FUZ            AGGLO5     REGION  \
# 1994     2023    CAWI  0.632694  60-69 ans  Communes rurales  Normandie
#
#       TYPLOG              TYPLOG2  NBPERS                 NBPERS5  ...  \
# 1994  Maison  Maison individuelle      12  Cinq personnes et plus  ...
#
#                                                    ENV5  \
# 1994  Je ne le fais pas et je ne compte pas le faire...
#
#                                                    ENV6  \
# 1994  Je ne le fais pas mais je compte le faire à l’...
#
#                                                    ENV7  \
# 1994  Je ne le fais pas mais je compte le faire à l’...
#
#                                                    ENV8  \
# 1994  Je ne le fais pas mais je compte le faire à l’...
#
#                                                    ENV9  \
# 1994  Je ne le fais pas et je ne compte pas le faire...
#
#                                                   ENV10  \
# 1994  Je ne le fais pas mais je compte le faire à l’...
#
#                                                   ENV11  \
# 1994  Je ne le fais pas mais je compte le faire à l’...
#
#                                     ENV6EXP_1  \
# 1994  Oui, pour des raisons environnementales
#
#                                     ENV6EXP_2              REV_TR7
# 1994  Oui, pour des raisons environnementales  De 900 à 1500 euros
#
# [1 rows x 263 columns]

# %% [markdown]
# On peut aussi créer de nouvelles variables, par exemple en créant une variable qui est la somme de deux variables préexistantes.

# %%
df["NBTIC_agg"] = df["NBTIC1"] + df["NBTIC2"]
print(df["NBTIC_agg"])
# Out:
# 0        2.0
# 1        3.0
# 2       11.0
# 3        6.0
# 4        4.0
#         ...
# 4279     3.0
# 4280     3.0
# 4281     3.0
# 4282     2.0
# 4283     2.0
# Name: NBTIC_agg, Length: 4284, dtype: float64

# %% [markdown]
# Partie II : la visualisation de donnée
#
# Nous allons maintenant nous intéresser à seaborn, un package très populaire pour la visualisation de donnnées. Nous allons produire trois types de figures. Elles auront trois objectifs : représenter une variable qualitative, représenter une variable qualitative en fonction d'une variable quantitative et finalement deux variables quantitatives l'une en fonction de l'autre.

# %%
sb.barplot(x = "NBTIC1", y = "NBTIC2", data = df, hue = "SEXE")
# Out:
# <Axes: xlabel='NBTIC1', ylabel='NBTIC2'>

# %% [markdown]
# On peut aussi personnalisser l'apparence visuelle de notre barplot.

# %%
sb.barplot(x = "NBTIC1", y = "NBTIC2", data = df, hue = "SEXE",  
           palette = "winter_r")
# Out:
# <Axes: xlabel='NBTIC1', ylabel='NBTIC2'>

# %% [markdown]
# On peut aussi ajouter des éléments qui favorisent la compréhensibilité du graphique, notamment un titre et des titres pour les axes.

# %%
sb.barplot(x = "SEXE", y = "NBTIC1", data = df, hue = "SEXE",  
           palette = "winter_r", order = ["Femme", "Homme"], estimator = "median")
plt.title("Nombre de téléphones possédés dans le foyer en fonction du genre")
plt.xlabel("Sexe")
plt.ylabel("Nombre de téléphones")
# Out:
# Text(0, 0.5, 'Nombre de téléphones')

# %% [markdown]
# On peut aussi représenter des données sous la forme d'un boxplot. Une visualisation assez pratique pour résumer une variable quantitative...

# %%
sb.boxplot(x = "NBTIC1", data = df)
# Out:
# <Axes: xlabel='NBTIC1'>

# %% [markdown]
# ...Voire résumer deux variables en même temps en démultipliant "les boîtes".

# %%
sb.boxplot(x = "NBTIC1", y = "NBTIC2", data = df)
# Out:
# <Axes: xlabel='NBTIC1', ylabel='NBTIC2'>

# %% [markdown]
# Même principe avec une variable qualitative et une quantitative. On peut ici aussi ajouter des titres, personnaliser l'apparence, ...

# %%
sb.boxplot(x = "NBTIC1", y = "SEXE", data = df, palette = "viridis", hue = "SEXE",
          order = ["Femme", "Homme"])
plt.title("Boîtes de Tuckey représentant divers indicateurs pour le nombre de téléphones en activité dans un foyer en fonction du genre")
plt.xlabel("Nombre de téléphones en activité")
plt.ylabel("Genre")
# Out:
# Text(0, 0.5, 'Genre')

# %% [markdown]
# Finalement on peut produire des nuages de points. Si on utilise des variables numériques continues il est plutôt facile de le représenter. En revanche, avec des variables discrètes il est utile d'introduire de l' "entropie" ou jitter pour éloigner les points les uns des autres et éviter qu'ils ne se supperposent ce que permet de faire la fonction stripplot de seaborn.

# %%
sb.stripplot(x = "NBTIC1", y = "NBTIC5", hue = "SEXE", data = df, jitter = 0.8)
# Out:
# <Axes: xlabel='NBTIC1', ylabel='NBTIC5'>

# %% [markdown]
# On peut d'ailleurs la personnaliser et ajouter des titres comme pour les autres.

# %%
sb.stripplot(x = "NBTIC1", y = "NBTIC5", hue = "SEXE", data = df, jitter = 0.8, 
            palette = "winter_r")
plt.title("Nombre de consoles en usage dans le foyer en fonction du nombre de téléphones et du genre")
plt.xlabel("Nombre de téléphones")
plt.ylabel("Nombre de consoles")
# Out:
# Text(0, 0.5, 'Nombre de consoles')

# %% [markdown]
# Nous allons désormais tenter de répondre à plusieurs questions un peu plus sociologiques. Les données du baromètre du numérique vont nous permettre de le faire. Pour commencer demandons nous s'il y a des inégalités d'accès à la fibre en fonction de divers critères sociaux.

# %%
from tabulate import tabulate

# Génération du tableau (pas très beau)
crosstab_table = pd.crosstab(df['TYPCONN2'], df['PCS8EGO'], normalize='columns') *100
crosstab_table = crosstab_table.round(2)

# Embellissement
styled_table = crosstab_table.style.format("{:.0f}").set_table_styles(
    [{'selector': 'th', 'props': [('font-size', '14px'), ('background', '#4CAF50'), ('color', 'white')]}]
).bar(color='lightblue', axis=1)

# Affichage dans Jupyter Notebook
styled_table
# Out:
# <style type="text/css">
# #T_4faf9 th {
#   font-size: 14px;
#   background: #4CAF50;
#   color: white;
# }
# #T_4faf9_row0_col0, #T_4faf9_row1_col2, #T_4faf9_row2_col1, #T_4faf9_row3_col1, #T_4faf9_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_4faf9_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 25.9%, transparent 25.9%);
# }
# #T_4faf9_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 59.9%, transparent 59.9%);
# }
# #T_4faf9_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 48.3%, transparent 48.3%);
# }
# #T_4faf9_row0_col4, #T_4faf9_row0_col5, #T_4faf9_row0_col6 {
#   width: 10em;
# }
# #T_4faf9_row0_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 61.9%, transparent 61.9%);
# }
# #T_4faf9_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 79.5%, transparent 79.5%);
# }
# #T_4faf9_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 83.2%, transparent 83.2%);
# }
# #T_4faf9_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 83.7%, transparent 83.7%);
# }
# #T_4faf9_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 71.1%, transparent 71.1%);
# }
# #T_4faf9_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 85.3%, transparent 85.3%);
# }
# #T_4faf9_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 96.3%, transparent 96.3%);
# }
# #T_4faf9_row1_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 94.8%, transparent 94.8%);
# }
# #T_4faf9_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 81.4%, transparent 81.4%);
# }
# #T_4faf9_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 91.4%, transparent 91.4%);
# }
# #T_4faf9_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 86.2%, transparent 86.2%);
# }
# #T_4faf9_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 85.4%, transparent 85.4%);
# }
# #T_4faf9_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 66.3%, transparent 66.3%);
# }
# #T_4faf9_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 40.7%, transparent 40.7%);
# }
# #T_4faf9_row2_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 60.2%, transparent 60.2%);
# }
# #T_4faf9_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 72.6%, transparent 72.6%);
# }
# #T_4faf9_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 34.7%, transparent 34.7%);
# }
# #T_4faf9_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 33.5%, transparent 33.5%);
# }
# #T_4faf9_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 49.6%, transparent 49.6%);
# }
# #T_4faf9_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 54.2%, transparent 54.2%);
# }
# #T_4faf9_row3_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 26.7%, transparent 26.7%);
# }
# #T_4faf9_row3_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 29.0%, transparent 29.0%);
# }
# #T_4faf9_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 77.6%, transparent 77.6%);
# }
# #T_4faf9_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 62.5%, transparent 62.5%);
# }
# #T_4faf9_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 52.4%, transparent 52.4%);
# }
# #T_4faf9_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 81.3%, transparent 81.3%);
# }
# #T_4faf9_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 80.1%, transparent 80.1%);
# }
# #T_4faf9_row4_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 75.3%, transparent 75.3%);
# }
# #T_4faf9_row4_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 70.1%, transparent 70.1%);
# }
# </style>
# <table id="T_4faf9">
#   <thead>
#     <tr>
#       <th class="index_name level0" >PCS8EGO</th>
#       <th id="T_4faf9_level0_col0" class="col_heading level0 col0" >Agri. exploitant, artisan, commerçant, chef d'entreprise</th>
#       <th id="T_4faf9_level0_col1" class="col_heading level0 col1" >Autre inactif</th>
#       <th id="T_4faf9_level0_col2" class="col_heading level0 col2" >Cadre et profession intellectuelle supérieure</th>
#       <th id="T_4faf9_level0_col3" class="col_heading level0 col3" >Employé</th>
#       <th id="T_4faf9_level0_col4" class="col_heading level0 col4" >Ouvrier</th>
#       <th id="T_4faf9_level0_col5" class="col_heading level0 col5" >Personne au foyer</th>
#       <th id="T_4faf9_level0_col6" class="col_heading level0 col6" >Profession Intermédiaire</th>
#       <th id="T_4faf9_level0_col7" class="col_heading level0 col7" >Retraité</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >TYPCONN2</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4faf9_level0_row0" class="row_heading level0 row0" >Non réponse</th>
#       <td id="T_4faf9_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_4faf9_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_4faf9_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_4faf9_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_4faf9_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_4faf9_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_4faf9_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_4faf9_row0_col7" class="data row0 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_4faf9_level0_row1" class="row_heading level0 row1" >Par la fibre optique de bout en bout / FttH</th>
#       <td id="T_4faf9_row1_col0" class="data row1 col0" >52</td>
#       <td id="T_4faf9_row1_col1" class="data row1 col1" >55</td>
#       <td id="T_4faf9_row1_col2" class="data row1 col2" >66</td>
#       <td id="T_4faf9_row1_col3" class="data row1 col3" >55</td>
#       <td id="T_4faf9_row1_col4" class="data row1 col4" >47</td>
#       <td id="T_4faf9_row1_col5" class="data row1 col5" >56</td>
#       <td id="T_4faf9_row1_col6" class="data row1 col6" >63</td>
#       <td id="T_4faf9_row1_col7" class="data row1 col7" >62</td>
#     </tr>
#     <tr>
#       <th id="T_4faf9_level0_row2" class="row_heading level0 row2" >Par le câble ou la fibre terminaison coaxiale</th>
#       <td id="T_4faf9_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_4faf9_row2_col1" class="data row2 col1" >10</td>
#       <td id="T_4faf9_row2_col2" class="data row2 col2" >9</td>
#       <td id="T_4faf9_row2_col3" class="data row2 col3" >9</td>
#       <td id="T_4faf9_row2_col4" class="data row2 col4" >8</td>
#       <td id="T_4faf9_row2_col5" class="data row2 col5" >7</td>
#       <td id="T_4faf9_row2_col6" class="data row2 col6" >4</td>
#       <td id="T_4faf9_row2_col7" class="data row2 col7" >6</td>
#     </tr>
#     <tr>
#       <th id="T_4faf9_level0_row3" class="row_heading level0 row3" >Par un autre moyen, y compris Box 4G</th>
#       <td id="T_4faf9_row3_col0" class="data row3 col0" >7</td>
#       <td id="T_4faf9_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_4faf9_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_4faf9_row3_col3" class="data row3 col3" >3</td>
#       <td id="T_4faf9_row3_col4" class="data row3 col4" >5</td>
#       <td id="T_4faf9_row3_col5" class="data row3 col5" >5</td>
#       <td id="T_4faf9_row3_col6" class="data row3 col6" >3</td>
#       <td id="T_4faf9_row3_col7" class="data row3 col7" >3</td>
#     </tr>
#     <tr>
#       <th id="T_4faf9_level0_row4" class="row_heading level0 row4" >Par une ligne ADSL</th>
#       <td id="T_4faf9_row4_col0" class="data row4 col0" >31</td>
#       <td

# %%
from tabulate import tabulate

# Génération du tableau (pas très beau)
crosstab_table = pd.crosstab(df['TYPCONN2'], df['DIPL5'], normalize='columns') *100
crosstab_table = crosstab_table.round(2)

# Embellissement
styled_table = crosstab_table.style.format("{:.0f}").set_table_styles(
    [{'selector': 'th', 'props': [('font-size', '14px'), ('background', '#4CAF50'), ('color', 'white')]}]
).bar(color='lightblue', axis=1)

# Affichage dans Jupyter Notebook
styled_table
# Out:
# <style type="text/css">
# #T_15c40 th {
#   font-size: 14px;
#   background: #4CAF50;
#   color: white;
# }
# #T_15c40_row0_col0 {
#   width: 10em;
# }
# #T_15c40_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 67.9%, transparent 67.9%);
# }
# #T_15c40_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 63.4%, transparent 63.4%);
# }
# #T_15c40_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 38.4%, transparent 38.4%);
# }
# #T_15c40_row0_col4, #T_15c40_row1_col0, #T_15c40_row2_col4, #T_15c40_row3_col4, #T_15c40_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_15c40_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 83.8%, transparent 83.8%);
# }
# #T_15c40_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 91.8%, transparent 91.8%);
# }
# #T_15c40_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 98.8%, transparent 98.8%);
# }
# #T_15c40_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 89.0%, transparent 89.0%);
# }
# #T_15c40_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 96.4%, transparent 96.4%);
# }
# #T_15c40_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 70.3%, transparent 70.3%);
# }
# #T_15c40_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 72.1%, transparent 72.1%);
# }
# #T_15c40_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 59.4%, transparent 59.4%);
# }
# #T_15c40_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 25.0%, transparent 25.0%);
# }
# #T_15c40_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 99.5%, transparent 99.5%);
# }
# #T_15c40_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 75.8%, transparent 75.8%);
# }
# #T_15c40_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 83.4%, transparent 83.4%);
# }
# #T_15c40_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 76.1%, transparent 76.1%);
# }
# #T_15c40_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 88.5%, transparent 88.5%);
# }
# #T_15c40_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 79.0%, transparent 79.0%);
# }
# #T_15c40_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 79.8%, transparent 79.8%);
# }
# </style>
# <table id="T_15c40">
#   <thead>
#     <tr>
#       <th class="index_name level0" >DIPL5</th>
#       <th id="T_15c40_level0_col0" class="col_heading level0 col0" >12-17 ans</th>
#       <th id="T_15c40_level0_col1" class="col_heading level0 col1" >BAC</th>
#       <th id="T_15c40_level0_col2" class="col_heading level0 col2" >BEPC</th>
#       <th id="T_15c40_level0_col3" class="col_heading level0 col3" >Diplômé du supérieur</th>
#       <th id="T_15c40_level0_col4" class="col_heading level0 col4" >Non diplômé</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >TYPCONN2</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15c40_level0_row0" class="row_heading level0 row0" >Non réponse</th>
#       <td id="T_15c40_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_15c40_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_15c40_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_15c40_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_15c40_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_15c40_level0_row1" class="row_heading level0 row1" >Par la fibre optique de bout en bout / FttH</th>
#       <td id="T_15c40_row1_col0" class="data row1 col0" >63</td>
#       <td id="T_15c40_row1_col1" class="data row1 col1" >53</td>
#       <td id="T_15c40_row1_col2" class="data row1 col2" >58</td>
#       <td id="T_15c40_row1_col3" class="data row1 col3" >62</td>
#       <td id="T_15c40_row1_col4" class="data row1 col4" >56</td>
#     </tr>
#     <tr>
#       <th id="T_15c40_level0_row2" class="row_heading level0 row2" >Par le câble ou la fibre terminaison coaxiale</th>
#       <td id="T_15c40_row2_col0" class="data row2 col0" >10</td>
#       <td id="T_15c40_row2_col1" class="data row2 col1" >7</td>
#       <td id="T_15c40_row2_col2" class="data row2 col2" >8</td>
#       <td id="T_15c40_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_15c40_row2_col4" class="data row2 col4" >11</td>
#     </tr>
#     <tr>
#       <th id="T_15c40_level0_row3" class="row_heading level0 row3" >Par un autre moyen, y compris Box 4G</th>
#       <td id="T_15c40_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_15c40_row3_col1" class="data row3 col1" >6</td>
#       <td id="T_15c40_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_15c40_row3_col3" class="data row3 col3" >5</td>
#       <td id="T_15c40_row3_col4" class="data row3 col4" >6</td>
#     </tr>
#     <tr>
#       <th id="T_15c40_level0_row4" class="row_heading level0 row4" >Par une ligne ADSL</th>
#       <td id="T_15c40_row4_col0" class="data row4 col0" >26</td>
#       <td id="T_15c40_row4_col1" class="data row4 col1" >34</td>
#       <td id="T_15c40_row4_col2" class="data row4 col2" >30</td>
#       <td id="T_15c40_row4_col3" class="data row4 col3" >27</td>
#       <td id="T_15c40_row4_col4" class="data row4 col4" >27</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Maintenant posons-nous une autre question : à quel point la possession des différents équipements informatiques est-elle corrélée ? Cette fois nous devons recourir à une analyse multivariée qui permette de résumer diverses variables en même temps. Les analyses factorielles, ici l'ACM (parce que nos variables sont catégorielles, sinon une ACP) est la plus habituelle

# %%
#pip install fanalysis

# %%
#On importe les packages 
import prince
from fanalysis.mca import MCA
import matplotlib.pyplot as plt

# %%
# On crée une nouvelle base qui ne contient que les variables que l'on veut introduire
df_ACM = pd.DataFrame(df[["TELFIXE", "TABLETTE", "TABLET2", "MICRO2", "PTSMART2", "SMARTPHO", "TELMODET", "TELMOB"]])
df_ACM["TELFIXE"] = df["TELFIXE"].astype("category")
df_ACM["TABLETTE"] = df["TABLETTE"].astype("category")
df_ACM["TABLET2"] = df["TABLET2"].astype("category")
df_ACM["MICRO2"] = df["MICRO2"].astype("category")
df_ACM["PTSMART2"] = df["PTSMART2"].astype("category")
df_ACM["SMARTPHO"] = df["SMARTPHO"].astype("category")
df_ACM["TELMODET"] = df["TELMODET"].astype("category")
df_ACM["TELMOB"] = df["TELMOB"].astype("category")
df_ACM.head(5)
df_ACM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4284 entries, 0 to 4283
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   TELFIXE   4284 non-null   category
#  1   TABLETTE  4284 non-null   category
#  2   TABLET2   4284 non-null   category
#  3   MICRO2    4284 non-null   category
#  4   PTSMART2  4284 non-null   category
#  5   SMARTPHO  4284 non-null   category
#  6   TELMODET  642 non-null    category
#  7   TELMOB    4284 non-null   category
# dtypes: category(8)
# memory usage: 34.8 KB

# %%
# Appliquer l'ACM avec fanalysis
mca = prince.MCA(
    n_components=4,
    n_iter=3,
    copy=True,
    check_input=True,
    engine='sklearn',
    random_state=42
)
mca = mca.fit(df_ACM)

# %%
#On imprime les coordonnées des colonnes, autrement dit des 
#différentes modalités des variables introduites
mca.column_coordinates(df_ACM)
# Out:
#                                                      0         1         2  \
# TELFIXE__Non                                  0.021848 -0.047816  0.546013
# TELFIXE__Non réponse                          0.498719 -0.640842  0.408683
# TELFIXE__Oui                                 -0.061881  0.015713 -0.136140
# TABLETTE__Non                                 0.463200 -0.615702  0.646771
# TABLETTE__Oui                                -0.567739  0.377454 -0.680386
# TABLETTE__[Nsp]                               1.867585  6.812632  3.591489
# TABLET2__Aucun                                0.463200 -0.615702  0.646771
# TABLET2__Plusieurs                           -0.648149  0.395374 -0.623217
# TABLET2__Un                                  -0.540444  0.371371 -0.699793
# TABLET2__[Nsp]                                1.867585  6.812632  3.591489
# MICRO2__MICRO2 1                             -0.331384 -0.001167  0.022081
# MICRO2__MICRO2 2                              1.539400  0.014484 -0.045776
# PTSMART2__Acheté neuf                        -0.427293  0.000671  0.048202
# PTSMART2__Acquis d’occasion ou reconditionné -0.355994  0.032454  0.388062
# PTSMART2__Non réponse                         1.339629  1.332006 -4.526062
# PTSMART2__Non, je n’en possède pas            2.016373 -0.058120 -0.543103
# SMARTPHO__Non                                 2.004973 -0.034702 -0.610198
# SMARTPHO__Oui                                -0.411506  0.007709  0.123456
# TELMODET__Acheté neuf                         1.641104 -0.488021 -0.173063
# TELMODET__Acquis d’occasion ou reconditionné  1.417993 -0.261165 -0.316698
# TELMODET__Non réponse                         3.308597  7.593484  3.248138
# TELMODET__Non, je n’en possède pas            2.760071  0.578858 -1.245116
# TELMOB__Non                                   2.701086  0.702607 -1.340520
# TELMOB__Oui                                  -0.203876 -0.039829  0.090811
#
#                                                      3
# TELFIXE__Non                                  0.153241
# TELFIXE__Non réponse                          2.474535
# TELFIXE__Oui                                 -0.027514
# TABLETTE__Non                                 0.208238
# TABLETTE__Oui                                -0.148884
# TABLETTE__[Nsp]                              -0.559015
# TABLET2__Aucun                                0.208238
# TABLET2__Plusieurs                            0.094663
# TABLET2__Un                                  -0.231556
# TABLET2__[Nsp]                               -0.559015
# MICRO2__MICRO2 1                              0.042401
# MICRO2__MICRO2 2                             -0.139399
# PTSMART2__Acheté neuf                         0.097133
# PTSMART2__Acquis d’occasion ou reconditionné  0.209334
# PTSMART2__Non réponse                         4.577485
# PTSMART2__Non, je n’en possède pas           -0.672267
# SMARTPHO__Non                                -0.583834
# SMARTPHO__Oui                                 0.121977
# TELMODET__Acheté neuf                        -2.250149
# TELMODET__Acquis d’occasion ou reconditionné -2.253458
# TELMODET__Non réponse                         0.916803
# TELMODET__Non, je n’en possède pas            2.250752
# TELMOB__Non                                   2.341858
# TELMOB__Oui                                  -0.121909

# %%
#Cette fois on imprime les contributions des différentes 
#modalités des variables
mca.column_contributions_.style.format('{:.0%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_bce18">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bce18_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_bce18_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_bce18_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_bce18_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bce18_level0_row0" class="row_heading level0 row0" >TELFIXE__Non</th>
#       <td id="T_bce18_row0_col0" class="data row0 col0" >0%</td>
#       <td id="T_bce18_row0_col1" class="data row0 col1" >0%</td>
#       <td id="T_bce18_row0_col2" class="data row0 col2" >4%</td>
#       <td id="T_bce18_row0_col3" class="data row0 col3" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_bce18_level0_row1" class="row_heading level0 row1" >TELFIXE__Non réponse</th>
#       <td id="T_bce18_row1_col0" class="data row1 col0" >0%</td>
#       <td id="T_bce18_row1_col1" class="data row1 col1" >0%</td>
#       <td id="T_bce18_row1_col2" class="data row1 col2" >0%</td>
#       <td id="T_bce18_row1_col3" class="data row1 col3" >1%</td>
#     </tr>
#     <tr>
#       <th id="T_bce18_level0_row2" class="row_heading level0 row2" >TELFIXE__Oui</th>
#       <td id="T_bce18_row2_col0" class="data row2 col0" >0%</td>
#       <td id="T_bce18_row2_col1" class="data row2 col1" >0%</td>
#       <td id="T_bce18_row2_col2" class="data row2 col2" >1%</td>
#       <td id="T_bce18_row2_col3" class="data row2 col3" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_bce18_level0_row3" class="row_heading level0 row3" >TABLETTE__Non</th>
#       <td id="T_bce18_row3_col0" class="data row3 col0" >3%</td>
#       <td id="T_bce18_row3_col1" class="data row3 col1" >9%</td>
#       <td id="T_bce18_row3_col2" class="data row3 col2" >11%</td>
#       <td id="T_bce18_row3_col3" class="data row3 col3" >1%</td>
#     </tr>
#     <tr>
#       <th id="T_bce18_level0_row4" class="row_heading level0 row4" >TABLETTE__Oui</th>
#       <td id="T_bce18_row4_col0" class="data row4 col0" >4%</td>
#       <td id="T_bce18_row4_col1" class="data row4 col1" >4%</td>
#       <td id="T_bce18_row4_col2" class="data row4 col2" >14%</td>
#       <td id="T_bce18_row4_col3" class="data row4 col3" >1%</td>
#     </tr>
#     <tr>
#       <th id="T_bce18_level0_row5" class="row_heading level0 row5" >TABLETTE__[Nsp]</th>
#       <td id="T_bce18_row5_col0" class="data row5 col0" >1%</td>
#       <td id="T_bce18_row5_col1" class="data row5 col1" >34%</td>
#       <td id="T_bce18_row5_col2" class="data row5 col2" >11%</td>
#       <td id="T_bce18_row5_col3" class="data row5 col3" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_bce18_level0_row6" class="row_heading level0 row6" >TABLET2__Aucun</th>
#       <td id="T_bce18_row6_col0" class="data row6 col0" >3%</td>
#       <td id="T_bce18_row6_col1" class="data row6 col1" >9%</td>
#       <td id="T_bce18_row6_col2" class="data row6 col2" >11%</td>
#       <td id="T_bce18_row6_col3" class="data row6 col3" >1%</td>
#     </tr>
#     <tr>
#       <th id="T_bce18_level0_row7" class="row_heading level0 row7" >TABLET2__Plusieurs</th>
#       <td id="T_bce18_row7_col0" class="data row7 col0" >1%</td>
#       <td id="T_bce18_row7_col1" class="data row7 col1" >1%</td>
#       <td id="T_bce18_row7_col2" class="data row7 col2" >3%</td>
#       <td id="T_bce18_row7_col3" class="data row7 col3" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_bce18_level0_row8" class="row_heading level0 row8" >TABLET2__Un</th>
#       <td id="T_bce18_row8_col0" class="data row8 col0" >3%</td>
#       <td id="T_bce18_row8_col1" class="data row8 col1" >3%</td>
#       <td id="T_bce18_row8_col2" class="data row8 col2" >11%</td>
#       <td id="T_bce18_row8_col3" class="data row8 col3" >1%</td>
#     </tr>
#     <tr>
#       <th id="T_bce18_level0_row9" class="row_heading level0 row9" >TABLET2__[Nsp]</th>
#       <td id="T_bce18_row9_col0" class="data row9 col0" >1%</td>
#       <td id="T_bce18_row9_col1" class="data row9 col1" >34%</td>
#       <td id="T_bce18_row9_col2" class="data row9 col2" >11%</td>
#       <td id="T_bce18_row9_col3" class="data row9 col3" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_bce18_level0_row10" class="row_heading level0 row10" >MICRO2__MICRO2 1</th>
#       <td id="T_bce18_row10_col0" class="data row10 col0" >3%</td>
#       <td id="T_bce18_row10_col1" class="data row10 col1" >0%</td>
#       <td id="T_bce18_row10_col2" class="data row10 col2" >0%</td>
#       <td id="T_bce18_row10_col3" class="data row10 col3" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_bce18_level0_row11" class="row_heading level0 row11" >MICRO2__MICRO2 2</th>
#       <td id="T_bce18_row11_col0" class="data row11 col0" >10%</td>
#       <td id="T_bce18_row11_col1" class="data row11 col1" >0%</td>
#       <td id="T_bce18_row11_col2" class="data row11 col2" >0%</td>
#       <td id="T_bce18_row11_col3" class="data row11 col3" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_bce18_level0_row12" class="row_heading level0 row12" >PTSMART2__Acheté neuf</th>
#       <td id="T_bce18_row12_col0" class="data row12 col0" >3%</td>
#       <td id="T_bce18_row12_col1" class="data row12 col1" >0%</td>
#       <td id="T_bce18_row12_col2" class="data row12 col2" >0%</td>
#       <td id="T_bce18_row12_col3" class="data row12 col3" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_bce18_level0_row13" class="row_heading level0 row13" >PTSMART2__Acquis d’occasion ou reconditionné</th>
#       <td id="T_bce18_row13_col0" class="data row13 col0" >1%</td>
#       <td id="T_bce18_row13_col1" class="data row13 col1" >0%</td>
#       <td id="T_bce18_row13_col2" class="data row13 col2" >2%</td>
#       <td id="T_bce18_row13_col3" class="data row13 col3" >1%</td>
#     </tr>
#     <tr>
#       <th id="T_bce18_level0_row14" class="row_heading level0 row14" >PTSMART2__Non réponse</th>
#       <td id="T_bce18_row14_col0" class="data row14 col0" >0%</td>
#       <td id="T_bce18_row14_col1" class="data row14 col1" >0%</td>
#       <td id="T_bce18_row14_col2" class="data row14 col2" >3%</td>
#       <td id="T_bce18_row14_col3" class="data row14 col3" >4%</td>
#     </tr>
#     <tr>
#       <th id="T_bce18_level0_row15" class="row_heading level0 row15" >PTSMART2__Non, je n’en possède pas</th>
#       <td id="T_bce18_row15_col0" class="data row15 col0" >16%</td>
#       <td id="T_bce18_row15_col1" class="data row15 col1" >0%</td>
#       <td id="T_bce18_row15_col2" class="data row15 col2" >3%</td>
#       <td id="T_bce18_row15_col3" class="data row15 col3" >5%</td>
#     </tr>
#     <tr>
#       <th id="T_bce18_level0_row16" class="row_heading level0 row16" >SMARTPHO__Non</th>
#       <td id="T_bce18_row16_col0" class="data row16 col0" >17%</td>
#       <td id="T_bce18_row16_col1" class="data row16 col1" >0%</td>
#       <td id="T_bce18_row16_col2" class="data row16 col2" >3%</td>
#       <td id="T_bce18_row16_col3" class="data row16 col3" >4%</td>
#     </tr>
#     <tr>
#       <th id="T_bce18_level0_row17" class="row_heading level0 row17" >SMARTPHO__Oui</th>
#       <td id="T_bce18_row17_col0" class="data row17 col0" >4%</td>
#       <td id="T_bce18_row17_col1" class="data row17 col1" >0%</td>
#       <td id="T_bce18_row17_col2" class="data row17 col2" >1%</td>
#       <td id="T_bce18_row17_col3" class="data row17 col3" >1%</td>
#     </tr>
#     <tr>
#       <th id="T_bce18_level0_row18" class="row_heading level0 row18" >TELMODET__Acheté neuf</th>
#       <td id="T_bce18_row18_col0" class="data row18 col0" >6%</td>
#       <td id="T_bce18_row18_col1" class="data row18 col1" >1%</td>
#       <td id="T_bce18_row18_col2" class="data row18 col2" >0%</td>
#       <td id="T_bce18_row18_col3" class="data row18 col3" >31%</td>
#     </tr>
#     <tr>
#       <th id="T_bce18_level0_row19" class="row_heading level0 row19" >TELMODET__Acquis d’occasion ou reconditionné</th>
#       <td id="T_bce18_row19_col0" class="data row19 col0" >1%</td>
#       <td id="T_bce18_row19_col1" class="data row19 col1" >0%</td>
#       <td id="T_bce18_row19_col2" class="data row19 col2" >0%</td>
#       <td id="T_bce18_row19_col3" class="data row19 col3" >5%</td>
#     <

# %%
mca.plot(
   df_ACM,
    x_component=0,
    y_component=1,
    show_column_markers=True,
    show_row_markers=False,
    show_column_labels=True,
    show_row_labels=False
)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# http://localhost:8888/files/visualization(1).svg?_xsrf=2%7Cb3a843e6%7C67dba56379799f46b78285609750f193%7C1742732138

# %%
plt.figure(figsize=(6, 4))
sb.countplot(x="CHAT2_1", data=df, order=["Oui", "Non", "Ne sait pas"], palette="pastel")
plt.title("Utilisation de l'IA dans un cadre professionnel ou d'études")
plt.xlabel("Réponse")
plt.ylabel("Nombre de répondants")
plt.show()

plt.figure(figsize=(6, 4))
sb.countplot(x="CHAT2_2", data=df, order=["Oui", "Non", "Ne sait pas"], palette="pastel")
plt.title("Utilisation de l'IA dans un cadre privé")
plt.xlabel("Réponse")
plt.ylabel("Nombre de répondants")
plt.show()
# Out:
# C:\Users\Arnaud\AppData\Local\Temp\ipykernel_19432\3542927607.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(x="CHAT2_1", data=df, order=["Oui", "Non", "Ne sait pas"], palette="pastel")
# C:\Users\Arnaud\AppData\Local\Temp\ipykernel_19432\3542927607.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(x="CHAT2_2", data=df, order=["Oui", "Non", "Ne sait pas"], palette="pastel")

# %%
# Filtrage des utilisateurs d'IA (professionnel ou privé), ceux ayant répondus oui à l'une ou l'autre des questions
users_ia = df[(df["CHAT2_1"] == "Oui") | (df["CHAT2_2"] == "Oui")]

age_order = ["12-17 ans", "18-24 ans", "25-39 ans", "40-59 ans", "60-69 ans", "70 ans et plus"]

# Graphique
plt.figure(figsize=(8, 5))
sb.countplot(y="AGE6FUZ", data=users_ia, order=age_order, palette="coolwarm")
plt.title("Tranche d'âge des utilisateurs d'IA (usage pro ou perso)")
plt.xlabel("Nombre de répondants")
plt.ylabel("Tranche d'âge")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Arnaud\AppData\Local\Temp\ipykernel_19432\956509439.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(y="AGE6FUZ", data=users_ia, order=age_order, palette="coolwarm")

# %%
income_order = [
    "Moins de 900 € par mois",
    "De 900 à 1500 euros",
    "De 1500 à 2300 euros",
    "De 2300 à 3100 euros",
    "De 3100 à 4000 euros",
    "4000 euros et plus",
    "Non déclaré (ne sait pas, refus)"
]

# Graphique
plt.figure(figsize=(9, 5))
sb.countplot(y="REV_TR7", data=users_ia, order=income_order, palette="viridis")
plt.title("Tranche de revenus des utilisateurs d'IA (usage pro ou perso)")
plt.xlabel("Nombre de répondants")
plt.ylabel("Tranche de revenus")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Arnaud\AppData\Local\Temp\ipykernel_19432\4099593648.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(y="REV_TR7", data=users_ia, order=income_order, palette="viridis")
